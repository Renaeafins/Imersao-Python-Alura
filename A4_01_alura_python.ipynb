# %%
# Participante: Renan D. D. Fiamoncini
# Esse código faz parte das atividades práticas que estou fazendo na Imersão Dados com Pyhton, da Alura, evento ocorrido nos dias 05 a 08 ago. 2025.
# Todos os conteúdos disponibilizados pela imersão ficam disponíveis na plataforma da Alura por tempo limitado para não assinantes da plataforma. Para rever a imersão após o prazo, é necessário ser estudante assinante da plataforma.

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
# Como dá pra ver na tabela acima, o Python analisa as linhas de tabela iniciando na linha nº 0.

# %%
# df = dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
# Agora, com o df.info(), conseguimos ver todas as linhas e o tipo de dado de cada uma.

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
# Pq só são trazidos dados numéricos? Pq essas análises são

# %%
df.shape
# Out:
# (133349, 11)

# %%
# df.shape nos deu o número de linhas e de colunas do arquivo puxado pelo df

# %%
# df.shape não tem o parênteses após ele pois é um atributo, não é método ou função

# %%
# df.shape é um vetor

# %%
linhas, colunas = df.shape[0], df.shape[1]

# %%
print("Linhas:", linhas)
print("Colunas", colunas)
# Out:
# Linhas: 133349
# Colunas 11

# %%
# Após declarar as variáveis 'linhas' e 'colunas', é preciso clicar no botão de play na esquerda, o de 'Executar célula', para que o print na linha seguinte possa acessá-las.

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
# Nesse momento, é comentado na aula sobre a parte de geração de código usando a I.A. do Google Gemini (associada/"embutida" ao Colab)
# Prompt pra usar: "traduza para mim todas as colunas do dataframe df para português brasileiro"

# %%
# Traduzindo as colunas para português brasileiro
colunas_traduzidas = {
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}

df = df.rename(columns=colunas_traduzidas)

# Exibindo as colunas traduzidas para verificar
display(df.columns)
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
# Mais adiante na aula, vimos que os nomes de colunas gerados pela I.A. não era muito práticos e voltamos para consertar.
# Por já termos mudado os nomes do inglẽs para portuguÊs anteriormente, tivemos que ir nas colunas_traduzidas e colocar dos nomes atuais para os novos.

# %%
# Verifiquei o prompt que me foi gerado e analisei o script gerado por conta própria e depois comparando com o gerado pelos instrutores/profs da aula.
# No final do script deles, foi gerada uma parte para que, a partir de então, fosse usada a df renomeada a partir de então. Isso foi gerado no meu um pouco diferente, mas deu certo, segue teste abaixo:

# %%
df.describe()
# Out:
#                  ano       salario            usd         remoto
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
# Para acessar uma coluna específica, usaremos:

# %%
df['senioridade'].value_counts()
# Out:
# senioridade
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
# SE = Sênior, MI = Mid/Intermediário, EN = Entry, EX = Executivo. Depois entenderemos melhor essas siglas.

# %%
df['contrato'].value_counts()
# Out:
# contrato
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
# FT = Fulltime, CT = Contrato Temporário, PT = Part-time, FL = Freelance

# %%
df['remoto'].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
# Para facilitar, voltaremos no script gerado pela I.A. e ajustaremos os nomes das colunas traduzidas.

# %%
# Na parte de rmotos, o 0 seria totalmente presencial (0% remoto), 100 seria totalmente rmoto (100% remoto), e 50 seria híbrido (50% remoto).

# %%
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
# M = Medium, L = Large, S = Small

# %%
# Além de renomearmos colunas anteriormente, pode ser relevante mudar o nome das siglas para que pessoas não especialistas consigam entender mais à frente no gráfico.
# Criaremos um dicionário para a renomeação.

# %%
# Prompt: "traduza para portugues brasileiro as categorias da coluna 'senioridade' do dataframe DF"

# %%
# Dicionário para traduzir as siglas da coluna 'senioridade'
senioridade_traduzida = {
    'SE': 'Sênior',
    'MI': 'Intermediário',
    'EN': 'Iniciante',
    'EX': 'Executivo'
}

# Renomeando os valores na coluna 'senioridade'
df['senioridade'] = df['senioridade'].replace(senioridade_traduzida)

# Exibindo os valores únicos e suas contagens na coluna 'senioridade' para verificar
display(df['senioridade'].value_counts())
# Out:
# senioridade
# Sênior           77241
# Intermediário    40465
# Iniciante        12443
# Executivo         3200
# Name: count, dtype: int64

# %%
# Copiei e colei o prompt da I.A. abaixo ajustando os nomes das senioridades:

# %%
# Dicionário para traduzir as siglas da coluna 'senioridade'
senioridade_traduzida = {
    'SE': 'Sênior',
    'MI': 'Pleno',
    'EN': 'Junior',
    'EX': 'Executivo'
}

# Renomeando os valores na coluna 'senioridade'
df['senioridade'] = df['senioridade'].replace(senioridade_traduzida)

# Exibindo os valores únicos e suas contagens na coluna 'senioridade' para verificar
display(df['senioridade'].value_counts())
# Out:
# senioridade
# Sênior           77241
# Intermediário    40465
# Iniciante        12443
# Executivo         3200
# Name: count, dtype: int64

# %%
# Prompt: "traduza para portugues brasileiro as categorias da coluna 'contrato' do dataframe DF"

# %%
# Dicionário para traduzir as siglas da coluna 'contrato'
contrato_traduzido = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Meio Período',
    'FL': 'Freelancer'
}

# Renomeando os valores na coluna 'contrato'
df['contrato'] = df['contrato'].replace(contrato_traduzido)

# Exibindo os valores únicos e suas contagens na coluna 'contrato' para verificar
display(df['contrato'].value_counts())
# Out:
# contrato
# Tempo Integral    132563
# Contrato             394
# Meio Período         376
# Freelancer            16
# Name: count, dtype: int64

# %%
# Prompt: "traduza para portugues brasileiro as categorias da coluna 'tamanho_empresa' do dataframe DF"

# %%
# Dicionário para traduzir as siglas da coluna 'tamanho_empresa'
tamanho_empresa_traduzido = {
    'M': 'Média',
    'L': 'Grande',
    'S': 'Pequeno'
}

# Renomeando os valores na coluna 'tamanho_empresa'
df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa_traduzido)

# Exibindo os valores únicos e suas contagens na coluna 'tamanho_empresa' para verificar
display(df['tamanho_empresa'].value_counts())
# Out:
# tamanho_empresa
# Média      129561
# Grande       3574
# Pequeno       214
# Name: count, dtype: int64

# %%
# Acima só troquei a tradução M = "Médio" para M = "Média"

# %%
# Prompt: "traduza para portugues brasileiro as categorias da coluna 'remoto' do dataframe DF"

# %%
# Dicionário para traduzir as categorias da coluna 'remoto'
remoto_traduzido = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}

# Renomeando os valores na coluna 'remoto'
df['remoto'] = df['remoto'].replace(remoto_traduzido)

# Exibindo os valores únicos e suas contagens na coluna 'remoto' para verificar
display(df['remoto'].value_counts())
# Out:
# remoto
# Presencial    105312
# Remoto         27718
# Híbrido          319
# Name: count, dtype: int64

# %%
# Vamos agora rever como ficou tudo traduzido:

# %%
df.head()
# Out:
#       ano    senioridade        contrato               cargo  salario moeda  \
# 0  2025.0         Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0         Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0  Intermediário  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0  Intermediário  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Iniciante  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Média
# 1  136000         US      Remoto      US           Média
# 2  158800         AU  Presencial      AU           Média
# 3  139200         AU  Presencial      AU           Média
# 4   90000         US  Presencial      US           Média

# %%
df.describe(include="object")
# Out:
#        senioridade        contrato           cargo   moeda residencia  \
# count       133349          133349          133349  133349     133349
# unique           4               4             390      26        102
# top         Sênior  Tempo Integral  Data Scientist     USD         US
# freq         77241          132563           17314  126140     119579
#
#             remoto empresa tamanho_empresa
# count       133349  133349          133349
# unique           3      95               3
# top     Presencial      US           Média
# freq        105312  119641          129561

# %%
# A tabela acima dá colunas categóricas e linhas.
# 'count' é a contagem de quantos valores temos para aquela coluna.
# 'unique' são valores únicos, para cada tipo de coisa (nº de tipos de senioridades, nº de tipos de contratos, nº de tipos de cargos, etc).
# 'top' é a linha de qual informação é mais frequente para cada coluna.
# 'freq' dá quantas vezes o valor do 'top' aparece, ou seja, quantas vezes o valor mais frequente aparece em cada caso.

# %%
# --- DIA 2 ---


# -------------

# %%
df.isnull()
# Out:
#           ano  senioridade  contrato  cargo  salario  moeda    usd  \
# 0       False        False     False  False    False  False  False
# 1       False        False     False  False    False  False  False
# 2       False        False     False  False    False  False  False
# 3       False        False     False  False    False  False  False
# 4       False        False     False  False    False  False  False
# ...       ...          ...       ...    ...      ...    ...    ...
# 133344  False        False     False  False    False  False  False
# 133345  False        False     False  False    False  False  False
# 133346  False        False     False  False    False  False  False
# 133347  False        False     False  False    False  False  False
# 133348  False        False     False  False    False  False  False
#
#         residencia  remoto  empresa  tamanho_empresa
# 0            False   False    False            False
# 1            False   False    False            False
# ...

# %%
# No df.isnull(), onde há dado nulo, é marcado 'true'. Onde não há dado nulo, é 'false'.

# %%
df.head()
# Out:
#       ano    senioridade        contrato               cargo  salario moeda  \
# 0  2025.0         Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0         Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0  Intermediário  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0  Intermediário  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Iniciante  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Média
# 1  136000         US      Remoto      US           Média
# 2  158800         AU  Presencial      AU           Média
# 3  139200         AU  Presencial      AU           Média
# 4   90000         US  Presencial      US           Média

# %%
df.isnull().sum()
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
# Acima, somamos todos os nulos, foram encontrados 10 anos não preenchidos na tabela.

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
# Nan = Not a Number
# Podemos exibir linhas com o 'nan'
# Relembrando: 'df' é a nossa base

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano    senioridade        contrato                      cargo  \
# 5588    NaN         Sênior  Tempo Integral            Product Manager
# 59692   NaN  Intermediário  Tempo Integral                   Engineer
# 59710   NaN      Iniciante  Tempo Integral             Data Scientist
# 59759   NaN         Sênior  Tempo Integral          Software Engineer
# 59789   NaN         Sênior  Tempo Integral                   Engineer
# 131000  NaN         Sênior  Tempo Integral  Machine Learning Engineer
# 131006  NaN         Sênior  Tempo Integral     Data Analytics Manager
# 133054  NaN      Iniciante  Tempo Integral             Data Scientist
# 133281  NaN  Intermediário  Tempo Integral  Machine Learning Engineer
# 133317  NaN  Intermediário  Tempo Integral             Data Scientist
#
#         salario moeda     usd residencia      remoto empresa tamanho_empresa
# 5588     184500   USD  184500         US  Presencial      US           Média
# ...

# %%
# O código acima significa que, dentro da nossa base, queremos ver tudo que tenha o isnull como true
# Ali, vemos todas as linhas da tabela com ano ausente (nan)

# %%
# Data science é tomar decisões com base em dados

# %%
# Vamos agora aprender como criar um dataframe do zero!
# Chamaremos nosso Data Frame de 'salarios' e chamaremos a biblioteca do panda (pd) para isso
# Também usaremos a biblioteca 'numpy'

# %%
import numpy as np

df_salarios = pd.DataFrame({
    'nome': ['Ana','Bruno','Carlos','Daniele','Val'],
    'salario': [4000,np.nan,5000,np.nan,100000]
})

# Tudo que for nulo preencheremos com a média do valor

# Calcula a média salarial e substitui os nulos pela média e arredonda os valores
df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))

''' Pra fazer grandes comentários, dá pra usar 3 aspas antes e depois do comentaŕio, funciona em linhas separadas
'''
# Calcula a mediana e substitui os nulos (nan) por essa mediana
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())
df_salarios
# df_salarios é nossa base - salario_media é a coluna que estamos criando nela - dentro dessa base, preencheremos o 'fillna' com a média (mean) dos salários - o round(2) arredonda as casas decimais
# Out:
#       nome   salario  salario_media  salario_mediana
# 0      Ana    4000.0        4000.00           4000.0
# 1    Bruno       NaN       36333.33           5000.0
# 2   Carlos    5000.0        5000.00           5000.0
# 3  Daniele       NaN       36333.33           5000.0
# 4      Val  100000.0      100000.00         100000.0

# %%
df_temperaturas = pd.DataFrame({
    "Dia": ['Segunda','Terça','Quarta','Quinta','Sexta'],
    'Temperatura': [30,np.nan,np.nan,28,27] })
# Não precisamos importar o np novamente na linha acima, já importamos anteriormente

# Usaremos o Forward Fill (ffill) abaixo para preencher as próximas casaas com o valor anterior
df_temperaturas['preenchido_ffill'] = df_temperaturas['Temperatura'].ffill()
df_temperaturas
# Out:
#        Dia  Temperatura  preenchido_ffill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              30.0
# 2   Quarta          NaN              30.0
# 3   Quinta         28.0              28.0
# 4    Sexta         27.0              27.0

# %%
df_temperaturas = pd.DataFrame({
    "Dia": ['Segunda','Terça','Quarta','Quinta','Sexta'],
    'Temperatura': [30,np.nan,np.nan,28,27] })
# Não precisamos importar o np novamente na linha acima, já importamos anteriormente

# Usaremos o Backwards Fill (bfill) abaixo para preencher casas anteriores com o valor seguinte/posterior, é o reverso do Forwards Fill (ffill)
df_temperaturas['preenchido_bfill'] = df_temperaturas['Temperatura'].bfill()
df_temperaturas
# Out:
#        Dia  Temperatura  preenchido_bfill
# 0  Segunda         30.0              30.0
# 1    Terça          NaN              28.0
# 2   Quarta          NaN              28.0
# 3   Quinta         28.0              28.0
# 4    Sexta         27.0              27.0

# %%
df_cidades = pd.DataFrame({
    'nome': ['Ana','Bruno','Carlos','Daniele','Val'],
    'cidade': ['São Paulo',np.nan,'Curitiba',np.nan,'Belém'] })

df_cidades['cidade_preenchida'] = df_cidades['cidade'].fillna('Não informada')
df_cidades
# Out:
#       nome     cidade cidade_preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Bruno        NaN     Não informada
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não informada
# 4      Val      Belém             Belém

# %%
df_limpo = df.dropna()
df_limpo.isnull().sum()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano    senioridade        contrato               cargo  salario moeda  \
# 0  2025.0         Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025.0         Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025.0  Intermediário  Tempo Integral       Data Engineer   158800   USD
# 3  2025.0  Intermediário  Tempo Integral       Data Engineer   139200   USD
# 4  2025.0      Iniciante  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa
# 0  214000         US      Remoto      US           Média
# 1  136000         US      Remoto      US           Média
# 2  158800         AU  Presencial      AU           Média
# 3  139200         AU  Presencial      AU           Média
# 4   90000         US  Presencial      US           Média

# %%
# Pq temos o ".0" nos anos, como "2025.0"?

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  object
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
# Vimos acima que a variável ano é do tipo "float64" enquanto algo como salário está com "int64". Vamos converter o tipo do ano de float64 para int64

# %%
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))
# Acima, colocamos o assign para que a coluna de ano receba ela mesma, mas com o tipo 'int64'
df_limpo
# Out:
#          ano    senioridade        contrato                     cargo  \
# 0       2025         Sênior  Tempo Integral        Solutions Engineer
# 1       2025         Sênior  Tempo Integral        Solutions Engineer
# 2       2025  Intermediário  Tempo Integral             Data Engineer
# 3       2025  Intermediário  Tempo Integral             Data Engineer
# 4       2025      Iniciante  Tempo Integral             Data Engineer
# ...      ...            ...             ...                       ...
# 133344  2020         Sênior  Tempo Integral            Data Scientist
# 133345  2021  Intermediário  Tempo Integral  Principal Data Scientist
# 133346  2020      Iniciante  Tempo Integral            Data Scientist
# 133347  2020      Iniciante        Contrato     Business Data Analyst
# 133348  2021         Sênior  Tempo Integral            Data Scientist
#
#         salario moeda     usd residencia      remoto empresa tamanho_empresa
# ...

# %%
# Aula 3 - Crie Gráficos e conte histórias com Dados

# %%
df_limpo['senioridade'].value_counts().plot(kind='bar', title='Distribuição da senioridade')
# Out:
# <Axes: title={'center': 'Distribuição da senioridade'}, xlabel='senioridade'>

# %%
# Dicas de bibliotecas para dados em python: "Matplotlib" e "Seaborn", dá pra ajudar elas pra melhorar a aparência dos gráficos

# %%
import seaborn as sns

# %%
sns.barplot(data=df_limpo, x='senioridade', y='usd')
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='senioridade', y='usd')
plt.title("Salário médio por senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário médio anual (USD)")
plt.show()

# %%
# Usaremos o método 'Group by' da biblioteca pandas para agrupar e ordenar coisas com base em uma estatística

# %%
df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False)
# 'mean' calculará a média
# 'sort' ordenará valores
# Out:
# senioridade
# Executivo        202027.667813
# Sênior           172850.838301
# Intermediário    143044.845979
# Iniciante         99034.963267
# Name: usd, dtype: float64

# %%
# Agora, vamos passar isso dentro de uma variável para passar como parâmetro para o Seaborn ordenar

# %%
ordem = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False).index
# ascending=False vai fazer ordem descendente (maior pro menor), se ele for true, será em ordem ascendente (menor para o maior)
# Quase idêntico à linha anterior, mas adicionamos o "ordem =" e o ".index"
# Vai pegar cada linha do index do dataframe e cria uma lista com a ordem que definimos

ordem
# Out:
# Index(['Executivo', 'Sênior', 'Intermediário', 'Iniciante'], dtype='object', name='senioridade')

# %%
# Copiamos e colamos o script anterior, adicionando "order=ordem" no final da parte do 'sns.barplot'
plt.figure(figsize=(8,5))
sns.barplot(data=df_limpo, x='senioridade', y='usd', order=ordem)
plt.title("Salário médio por senioridade")
plt.xlabel("Senioridade")
plt.ylabel("Salário médio anual (USD)")
plt.show()

# %%
plt.figure(figsize=(10,2))
sns.histplot(df_limpo['usd'],bins=50,kde=True)
plt.title("Distribuição salarial anual")
plt.xlabel("Média salarial anual (USD)")
plt.ylabel("Frequência")
plt.show()

# No 'plt.figure', os nºs do 'figsize' ajudam a definir o nº de colunas e o nº de linhas haverá no gráfico.
# Bins são a largura das barras que aparecem
# O kde é a linha de referência que passa pelas barras

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df_limpo['usd'])
plt.xlabel("Média salarial anual (USD)")
plt.show()

''' A caixa do gráfico tem 2 pontas, que mostram a variância de mín. e máx.
    Tem a mediana também na caixa
    E as bolinhas são
'''
# Out:
# ' A caixa do gráfico tem 2 pontas, que mostram a variância de mín. e máx.\n    Tem a mediana também na caixa\n    E as bolinhas são\n'

# %%
ordem_senioridade = ['Iniciante','Intermediário','Sênior','Executivo']
# Obs.: acima, os nomes dentro da ordem_senioridade devem estar iguais aos declarados no df

# Além disso, adicionaremos paleta nova de cores
sns.boxplot(x='senioridade',y='usd',data=df_limpo, order=ordem_senioridade, palette='Set2', hue='senioridade')
plt.title('Boxplot da distribuição por senioridade')
plt.xlabel('Salário em USD')
plt.show()

# %%
import plotly.express as px

# %%
senioridade_media_salario = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False).reset_index()

fig = px.bar(senioridade_media_salario,
             x='senioridade',
             y='usd',
             title='Média Salarial por Senioridade',
             labels={'senioridade':'Nível de Senioridade', 'usd':'Média Salarial Anual (USD)'})

fig.show()

# Agora, temos um gráfico interativo, mostrando detalhes ao passar com o mouse por cima das barras
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()

# Vamos redefinir as colunas do que estamos calculando:
remoto_contagem.columns = ['tipo_trabalho','quantidade']

# De px.bar (gráfico de barras), trocaremos para px.pie
fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Para converter esse gráfico de pizza em um de rosca, podemos fazer:

remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho','quantidade']

fig = px.pie(remoto_contagem,
             names='tipo_trabalho',
             values='quantidade',
             title='Proporção dos tipos de trabalho',
             # Adicionaremos aqui o necessário para transformá-lo
             hole=0.5)

# Agora, vamos colocar porcentagem e o nome para cada tipo de trabalho dentro da rosca
fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo
# Out:
#          ano    senioridade        contrato                     cargo  \
# 0       2025         Sênior  Tempo Integral        Solutions Engineer
# 1       2025         Sênior  Tempo Integral        Solutions Engineer
# 2       2025  Intermediário  Tempo Integral             Data Engineer
# 3       2025  Intermediário  Tempo Integral             Data Engineer
# 4       2025      Iniciante  Tempo Integral             Data Engineer
# ...      ...            ...             ...                       ...
# 133344  2020         Sênior  Tempo Integral            Data Scientist
# 133345  2021  Intermediário  Tempo Integral  Principal Data Scientist
# 133346  2020      Iniciante  Tempo Integral            Data Scientist
# 133347  2020      Iniciante        Contrato     Business Data Analyst
# 133348  2021         Sênior  Tempo Integral            Data Scientist
#
#         salario moeda     usd residencia      remoto empresa tamanho_empresa
# ...

# %%
# Desafio do dia 3: pra próx. aula, criar um gráfico que mostre salário por país para o cargo de cientista de dados (Data Scientist)
'''Data Scientist
  - salario
    - país
'''
# Out:
# 'Data Scientist\n  - salario\n    - país\n'

# %%
''' Desafio do dia 3: pra próx. aula, criar um gráfico que mostre salário por país para o cargo de cientista de dados (Data Scientist)
    Preferi ver o dia 4 diretamente e como os próprios professores resolveram o problema, ainda tenho dificuldade de fazer por conta própria nesse momento.
'''
# Out:
# ' Os dados principais são salário e país, que serão representados em colunas e linhas\n    Porém dentro, só considerar esses dados dentro do cargo de cientista de dados\n    (espaço pendente - acompanharei o dia 4 antes de fazer a atividade do dia 3)\n'

# %%
# Dia 4 - Construa um Dashboard Interativo

''' Vamos iniciar instalando o Python no computador, pelo site https://python.org/
    E também o VS Code (eu já tinha instalado)

    Boa parte da aula foi no VS Code, mas abaixo faremos o gráfico do desafio de ontem:
'''

# %%
pip install pycountry

# %%
import pycountry

# %%
# A tabela abaixo é a do desafio do dia 3, mas feita pelos professores, optei por não fazer o desafio.

# Função para converter ISO-2 para ISO-3
def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

# Criar nova coluna com código ISO-3
df_limpo['residencia_iso3'] = df_limpo['residencia'].apply(iso2_to_iso3)

# Calcular média salarial por país (ISO-3)
df_ds = df_limpo[df_limpo['cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['usd'].mean().reset_index()

# Gerar o mapa
fig = px.choropleth(media_ds_pais,
                    locations='residencia_iso3',
                    color='usd',
                    color_continuous_scale='rdylgn',
                    title='Salário médio de Cientista de Dados por país',
                    labels={'usd': 'Salário médio (USD)', 'residencia_iso3': 'País'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head()
# Out:
#     ano    senioridade        contrato               cargo  salario moeda  \
# 0  2025         Sênior  Tempo Integral  Solutions Engineer   214000   USD
# 1  2025         Sênior  Tempo Integral  Solutions Engineer   136000   USD
# 2  2025  Intermediário  Tempo Integral       Data Engineer   158800   USD
# 3  2025  Intermediário  Tempo Integral       Data Engineer   139200   USD
# 4  2025      Iniciante  Tempo Integral       Data Engineer    90000   USD
#
#       usd residencia      remoto empresa tamanho_empresa residencia_iso3
# 0  214000         US      Remoto      US           Média             USA
# 1  136000         US      Remoto      US           Média             USA
# 2  158800         AU  Presencial      AU           Média             AUS
# 3  139200         AU  Presencial      AU           Média             AUS
# 4   90000         US  Presencial      US           Média             USA

# %%
df_limpo.to_csv('dados-imersao-final.csv', index=False)
